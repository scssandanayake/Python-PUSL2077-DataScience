# %% [markdown]
# ## Data Visualization Using Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sicd = pd.read_csv(r"D:\python for DS\srilanka covid data.csv")

# %%
sicd.describe()
# Out:
#         time line    total_cases    new_cases  new_cases_smoothed  \
# count  461.000000     461.000000   461.000000          456.000000
# mean   231.000000   25275.407809   238.312364          230.790090
# std    133.223496   34311.244210   311.024985          282.873668
# min      1.000000       1.000000     0.000000            0.000000
# 25%    116.000000    1055.000000     6.000000            7.857000
# 50%    231.000000    3234.000000    35.000000           39.285500
# 75%    346.000000   46248.000000   459.000000          450.786000
# max    461.000000  109862.000000  1716.000000         1325.143000
#
#        total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count    400.000000   400.00000           456.000000               461.000000
# mean     159.842500     1.71750             1.448325              1180.363024
# std      211.899921     2.67218             1.904914              1602.337048
# ...

# %%
sicd.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# time line                                  int64
# total_cases                                int64
# new_cases                                  int64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# ...

# %%
sicd.shape
# Out:
# (461, 60)

# %% [markdown]
# ### two ways to create matplotlib plots
# 1. funtional approach: using the basic matplotlib commands ,we can easily create a plot

# %%
plt.plot(sicd['time line'], sicd['total_cases'])

# %% [markdown]
# ### object oriented approach
#
# 2.object oriented interface: this is the best way to create plots.the concept is create figure objects and call methods off it.creating a blank figure using the .figure() method

# %%
fig = plt.figure() #creeate a figure containing a single axis
ax =fig.add_axes([0,0,3,1]) #left,bottom,width,height
ax.plot(sicd['time line'],sicd['total_cases'])

# %%
fig, axbetween different grphs= plt.subplots() #create a figure and an axis
ax.plot(sicd['time lin,label='Total Cases'e'],sicd['total_cases'],label='Total Cases') #plot some data on axis

# %%
import matplotlib.pyplot as plto 
fig.a = plt.subplots(1,2) #no. of rows no. of coloumns
fig.tight_layout(pad = 2) #differenet between  different graphs

# %%
fig, a = plt.subplots(2,2, sharex = 'col') #sharey = 'row'
#or can specify as well

x = sicd['time line']
y = sicd['total_cases',]
