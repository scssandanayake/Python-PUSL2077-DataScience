# %% [markdown]
# # Data cleaning
#
#         - feature engireering
#         - cleaning & preprocessing
#             - cleaning techniques:
#             - Preprocessing techniques:
#             * do cleaniing first and then do the preprocessinng

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\User\Desktop\R lec\Datasets\Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
head(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 head(df)
#
# NameError: name 'head' is not defined

# %%
#first 4 rows of the dataset
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Last 4 rows of the dataset
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.isnull()   # Checking missing values
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum() # Checking missing value by variable
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df2 = pd.read_csv(r"C:\Users\User\Desktop\R lec\Datasets\Student.csv")

# %%
df2
# Out:
#      student_id school sex   age address_type              family_size  \
# 0             1     GP   F  18.0        Urban           Greater than 3
# 1             2     GP   F  17.0        Urban           Greater than 3
# 2             3     GP   F  15.0        Urban  Less than or equal to 3
# 3             4     GP   F  15.0        Urban           Greater than 3
# 4             5     GP   F  16.0        Urban           Greater than 3
# ..          ...    ...  ..   ...          ...                      ...
# 644         645     MS   F  19.0        Rural           Greater than 3
# 645         646     MS   F  18.0        Urban  Less than or equal to 3
# 646         647     MS   F  18.0        Urban           Greater than 3
# 647         648     MS   M  17.0        Urban  Less than or equal to 3
# 648         649     MS   M  18.0        Rural  Less than or equal to 3
#
#        parent_status               mother_education  \
# 0              Apart               higher education
# ...

# %%
df2.head()
# Out:
#    student_id school sex   age address_type              family_size  \
# 0           1     GP   F  18.0        Urban           Greater than 3
# 1           2     GP   F  17.0        Urban           Greater than 3
# 2           3     GP   F  15.0        Urban  Less than or equal to 3
# 3           4     GP   F  15.0        Urban           Greater than 3
# 4           5     GP   F  16.0        Urban           Greater than 3
#
#      parent_status               mother_education  \
# 0            Apart               higher education
# 1  Living together  primary education (4th grade)
# 2  Living together  primary education (4th grade)
# 3  Living together               higher education
# 4  Living together            secondary education
#
#                 father_education mother_job  ... family_relationship  \
# 0               higher education    at_home  ...                 4.0
# 1  primary education (4th grade)    at_home  ...                 5.0
# ...

# %%
df2.describe()
# Out:
#        student_id         age  class_failures  family_relationship  \
# count  649.000000  646.000000      647.000000           647.000000
# mean   325.000000   16.750774        0.222566             3.928903
# std    187.494444    1.216727        0.594024             0.956265
# min      1.000000   15.000000        0.000000             1.000000
# 25%    163.000000   16.000000        0.000000             4.000000
# 50%    325.000000   17.000000        0.000000             4.000000
# 75%    487.000000   18.000000        0.000000             5.000000
# max    649.000000   22.000000        3.000000             5.000000
#
#         free_time      social  weekday_alcohol  weekend_alcohol      health  \
# count  641.000000  644.000000       644.000000       646.000000  646.000000
# mean     3.184087    3.187888         1.506211         2.281734    3.529412
# std      1.051990    1.177990         0.927358         1.286016    1.446161
# ...

# %%
df2.isnull()
# Out:
#      student_id  school    sex    age  address_type  family_size  \
# 0         False   False  False  False         False        False
# 1         False   False  False  False         False        False
# 2         False   False  False  False         False        False
# 3         False   False  False  False         False        False
# 4         False   False  False  False         False        False
# ..          ...     ...    ...    ...           ...          ...
# 644       False   False  False  False         False        False
# 645       False   False  False  False         False        False
# 646       False   False  False  False         False        False
# 647       False   False  False  False         False        False
# 648       False   False  False  False         False        False
#
#      parent_status  mother_education  father_education  mother_job  ...  \
# 0            False             False             False       False  ...
# ...

# %%
df2.isnull().sum()
# Out:
# student_id               0
# school                   0
# sex                      0
# age                      3
# address_type             0
# family_size              0
# parent_status            0
# mother_education         0
# father_education         0
# mother_job               0
# father_job               0
# school_choice_reason     0
# guardian                 0
# travel_time              4
# study_time               3
# class_failures           2
# school_support           0
# family_support           0
# extra_paid_classes       0
# activities               0
# nursery_school           0
# higher_ed                0
# internet_access          0
# romantic_relationship    0
# family_relationship      2
# free_time                8
# social                   5
# weekday_alcohol          5
# weekend_alcohol          3
# health                   3
# absences                 1
# grade_1                  9
# grade_2                  3
# final_grade              0
# ...
