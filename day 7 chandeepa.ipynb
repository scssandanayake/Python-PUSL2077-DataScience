# %% [markdown]
# ## Data Visualization Libraries

# %% [markdown]
# #### Matplotlib
# #### Seaborn
# #### Steamlit

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sldc = pd.read_csv(r"F:\Year 2 Sem 2\Data Science in Python\Datasets\srilanka covid data.csv")

# %%
sldc.head()
# Out:
#   iso_code continent   location       date  time line  total_cases  new_cases  \
# 0      LKA      Asia  Sri Lanka  1/27/2020          1            1          1
# 1      LKA      Asia  Sri Lanka  1/28/2020          2            1          0
# 2      LKA      Asia  Sri Lanka  1/29/2020          3            1          0
# 3      LKA      Asia  Sri Lanka  1/30/2020          4            1          0
# 4      LKA      Asia  Sri Lanka  1/31/2020          5            1          0
#
#    new_cases_smoothed  total_deaths  new_deaths  ...  gdp_per_capita  \
# 0                 NaN           NaN         NaN  ...       11669.077
# 1                 NaN           NaN         NaN  ...       11669.077
# 2                 NaN           NaN         NaN  ...       11669.077
# 3                 NaN           NaN         NaN  ...       11669.077
# 4                 NaN           NaN         NaN  ...       11669.077
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
sldc.describe()
# Out:
#         time line    total_cases    new_cases  new_cases_smoothed  \
# count  461.000000     461.000000   461.000000          456.000000
# mean   231.000000   25275.407809   238.312364          230.790090
# std    133.223496   34311.244210   311.024985          282.873668
# min      1.000000       1.000000     0.000000            0.000000
# 25%    116.000000    1055.000000     6.000000            7.857000
# 50%    231.000000    3234.000000    35.000000           39.285500
# 75%    346.000000   46248.000000   459.000000          450.786000
# max    461.000000  109862.000000  1716.000000         1325.143000
#
#        total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count    400.000000   400.00000           456.000000               461.000000
# mean     159.842500     1.71750             1.448325              1180.363024
# std      211.899921     2.67218             1.904914              1602.337048
# ...

# %% [markdown]
# #### Two ways to create a matplotlib plot

# %% [markdown]
# #### 1)Functional Appraoch

# %%
plt.plot(sldc['time line'],sldc['total_cases'])

# %% [markdown]
# #### Object oriented approach

# %%
fig = plt.figure() #create a figure conatining a single axes
ax = fig.add_axes([0,0,3,1]) #left,bottom,width,height
ax.plot(sldc['time line'],sldc['total_cases'])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(sldc['time line'], sldc['total_cases'], label='total_cases')
ax.set_xlabel('Time Line')
ax.set_ylabel('Total Cases')
ax.set_title('Covid cumulative')
ax.legend(loc='best')

plt.show()

# %% [markdown]
# ### Subplots

# %%
fig,a = plt.subplots(1,2) #no of rows,no of columns
#fig.tight_Layout(pad=2)#difference between diffrent graphs(axes).There are 4 axes

# %%
fig,b=plt.subplots(2,2) #4 subplots in a fig

# %% [markdown]
# ### Visualize the subplots

# %%
x = sldc['time line']
y = ['total_cases', 'new_cases', 'total_deaths', 'new_deaths']

# Create subplots
fig, a = plt.subplots(2, 2, sharex='col')  # sharex='row' if you prefer

# Plot each data on its corresponding subplot
a[0][0].plot(x, sldc[y[0]])
a[0][0].set_title(y[0])

a[0][1].plot(x, sldc[y[1]])
a[0][1].set_title(y[1])

a[1][0].plot(x, sldc[y[2]])
a[1][0].set_title(y[2])

a[1][1].plot(x, sldc[y[3]])
a[1][1].set_title(y[3])

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
x = sldc['time line']
y = ['cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers', 'male_smokers']

fig, a = plt.subplots(2, 2, sharex='col')

a[0][0].plot(x, sldc[y[0]])
a[0][0].set_title(y[0])

a[0][1].plot(x, sldc[y[1]])
a[0][1].set_title(y[1])

a[1][0].plot(x, sldc[y[2]])
a[1][0].set_title(y[2])

a[1][1].plot(x, sldc[y[3]])
a[1][1].set_title(y[3])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insets

# %% [markdown]
# ##### Plot insoide a plot

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
fig, (ax, ax2) = plt.subplots(1, 2, figsize=[3*2, 3])  # axes sizes are given under figsize
fig.tight_layout(pad=2)
axins = inset_axes(ax, width=1.3, height=0.9)
axins2 = inset_axes(ax2, width="30%", height="40%", loc=4)
ax.tick_params(labelleft=False, labelbottom=False)

# %% [markdown]
# ### Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("F:\Year 2 Sem 2\Data Science in Python\Datasets\srilanka covid data.csv")

# %%
plt.scatter(df.new_tests,df.new_cases)
plt.show()

# %%
plt.scatter(df.total_cases,df.new_tests)

# %%
fig,ax = plt.subplots(figsize=(12,3))
sns.scatterplot(data=df,x="total_cases",y="new_tests",ax=ax)
# Out:
# <Axes: xlabel='total_cases', ylabel='new_tests'>
